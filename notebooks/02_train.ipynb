# %% [markdown]
# # 02 - Training
#
# Runs on GPU.
#
# This notebook only reads from `data/processed/`. It does not clean and it does not re-split - otherwise every run would train on slightly different data, and the runs could not be compared.
#
# What happens here: load the frozen split, run training with one specific configuration, save the results to a file in `results/metrics/` and the LoRA weights to Drive.
